# %%
import pandas as pd
import numpy as np

# %%
test = pd.read_csv("../test.csv")

# %%
test.pivot_table(index="Trap", columns="Species", aggfunc=len, values="Id")
# Out:
# Species  CULEX ERRATICUS  CULEX PIPIENS  CULEX PIPIENS/RESTUANS  \
# Trap
# T001                  95             95                      95
# T002                  95            103                     161
# T002A                 95             95                      95
# T002B                 95             95                      95
# T003                  95             95                     113
# T004                  95             95                      95
# T005                  95             95                      95
# T006                  95             95                      95
# T007                  95             95                      95
# T008                  95             96                     150
# T009                 190            191                     195
# T011                  95            100                     134
# T012                  95             97                     105
# T013                  95             95                     104
# ...

# %%
test.Species.unique()
# Out:
# array(['CULEX PIPIENS/RESTUANS', 'CULEX RESTUANS', 'CULEX PIPIENS',
#        'CULEX SALINARIUS', 'CULEX TERRITANS', 'CULEX TARSALIS',
#        'UNSPECIFIED CULEX', 'CULEX ERRATICUS'], dtype=object)

# %%
train = pd.read_csv("../train.csv")

# %%
train.pivot_table(index="Trap", columns="Species", aggfunc=len, values='Date')
# Out:
# Species  CULEX ERRATICUS  CULEX PIPIENS  CULEX PIPIENS/RESTUANS  \
# Trap
# T001                 NaN              6                       8
# T002                 NaN             41                      83
# T003                 NaN             26                      60
# T004                 NaN              5                       5
# T005                 NaN              5                       8
# T006                 NaN              7                      10
# T007                 NaN              9                      10
# T008                 NaN             28                      70
# T009                 NaN             23                      51
# T011                 NaN             28                      63
# T012                 NaN             19                      56
# T013                 NaN             20                      57
# T014                 NaN             11                      12
# T015                 NaN             10                      13
# ...
