# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
test = pd.read_csv("../test.csv")
weather = pd.read_csv("../weather_additional_info.csv")

# %%
weather.head()
# Out:
#    Station        Date  Tmax  Tmin  Tavg     Depart  DewPoint  WetBulb  Heat  \
# 0        1  2007-05-01    83    50    67  14.000000        51       56     0
# 1        2  2007-05-01    84    52    68   1.954484        51       57     0
# 2        1  2007-05-02    59    42    51  -3.000000        42       47    14
# 3        2  2007-05-02    60    43    52   1.954484        42       47    13
# 4        1  2007-05-03    66    46    56   2.000000        40       48     9
#
#    Cool       ...         Year  Month  Tavg_week  precip_week  heat_dw  \
# 0     2       ...         2007      5  59.428571     0.002143        0
# 1     3       ...         2007      5  60.833333     0.000714        0
# 2     0       ...         2007      5  59.428571     0.002143        0
# 3     0       ...         2007      5  60.833333     0.000714        0
# 4     0       ...         2007      5  59.428571     0.002143        0
#
# ...

# %%
weather.pivot_table(index="Month", aggfunc='mean')
# Out:
#        3_week_avrgPrecipTotal  3_week_avrgTavg  5_week_avrgPrecipTotal  \
# Month
# 5                    0.123945        59.508172                0.121883
# 6                    0.156632        68.411111                0.151063
# 7                    0.137220        75.133511                0.141595
# 8                    0.157770        74.830684                0.156544
# 9                    0.129659        69.713053                0.135872
# 10                   0.084721        58.521332                0.092133
#
#        5_week_avrgTavg  AvgSpeed       Cool    Depart  Depth   DewPoint  \
# Month
# 5            59.308282  9.739113   2.419878  2.080064      0  46.312500
# 6            66.044755  8.858455   7.027083  2.225159      0  56.927083
# 7            73.896613  8.003831  10.746964  1.838129      0  60.796371
# 8            75.245105  7.427879   9.382591  1.983290      0  61.030242
# 9            71.352293  8.118163   3.640167  1.818909      0  53.475000
# ...

# %%
# %pylab inline
sns.
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
weathert.pivot_table(index="Trap", columns="Species", aggfunc=len, values="Id")

# %%
test.Species.unique()
# Out:
# array(['CULEX PIPIENS/RESTUANS', 'CULEX RESTUANS', 'CULEX PIPIENS',
#        'CULEX SALINARIUS', 'CULEX TERRITANS', 'CULEX TARSALIS',
#        'UNSPECIFIED CULEX', 'CULEX ERRATICUS'], dtype=object)

# %%
train = pd.read_csv("../train.csv")

# %%
train.pivot_table(index="Trap", columns="Species", aggfunc=len, values='Date')
# Out:
# Species  CULEX ERRATICUS  CULEX PIPIENS  CULEX PIPIENS/RESTUANS  \
# Trap
# T001                 NaN              6                       8
# T002                 NaN             41                      83
# T003                 NaN             26                      60
# T004                 NaN              5                       5
# T005                 NaN              5                       8
# T006                 NaN              7                      10
# T007                 NaN              9                      10
# T008                 NaN             28                      70
# T009                 NaN             23                      51
# T011                 NaN             28                      63
# T012                 NaN             19                      56
# T013                 NaN             20                      57
# T014                 NaN             11                      12
# T015                 NaN             10                      13
# ...
