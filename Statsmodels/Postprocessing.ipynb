# %%
import pandas as pd

# %% [markdown]
# #Set non-vector species to 0

# %%
yhat = pd.read_csv('bag_subm_mean.csv')
yhat2 = yhat.copy()
yhat3 = yhat.copy()

# %%
df_support = pd.read_csv('../test.csv')
df_suppoert_train = pd.read_csv('../train.csv')

yhat2.WnvPresent[df_support.Species=='CULEX TARSALIS']=0
yhat2.WnvPresent[df_support.Species=='CULEX ERRATICUS']=0
yhat2.WnvPresent[df_support.Species=='UNSPECIFIED CULEX']=0

yhat3.WnvPresent[df_support.Species=='CULEX TARSALIS']=0
yhat3.WnvPresent[df_support.Species=='CULEX ERRATICUS']=0
# Out:
# /home/thomas/anaconda3/lib/python3.4/site-packages/IPython/kernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/thomas/anaconda3/lib/python3.4/site-packages/IPython/kernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/thomas/anaconda3/lib/python3.4/site-packages/IPython/kernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
yhat3 = yhat3.drop('Id',axis=1)

#(yhat2 == yhat3).all()

# %%
df_support.Species.values
# Out:
# array(['CULEX PIPIENS/RESTUANS', 'CULEX RESTUANS', 'CULEX PIPIENS', ...,
#        'CULEX TARSALIS', 'UNSPECIFIED CULEX', 'CULEX ERRATICUS'], dtype=object)

# %%
yhat3.index +=1
yhat3.to_csv('test3.csv',index_label='Id')

# %%
yhat2
# Out:
#             Id  WnvPresent
# 0            1      0.0060
# 1            2      0.0029
# 2            3      0.0041
# 3            4      0.0029
# 4            5      0.0039
# 5            6      0.0000
# 6            7      0.0000
# 7            8      0.0000
# 8            9      0.0035
# 9           10      0.0021
# 10          11      0.0031
# 11          12      0.0022
# 12          13      0.0028
# 13          14      0.0000
# 14          15      0.0000
# 15          16      0.0000
# 16          17      0.0028
# 17          18      0.0019
# 18          19      0.0028
# 19          20      0.0019
# 20          21      0.0021
# 21          22      0.0000
# 22          23      0.0000
# 23          24      0.0000
# 24          25      0.0027
# 25          26      0.0019
# 26          27      0.0031
# 27          28      0.0019
# 28          29      0.0021
# 29          30      0.0000
# ...        ...         ...
# 116263  116264      0.0954
# 116264  116265      0.0556
# ...
